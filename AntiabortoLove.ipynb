# %%
from gensim.models import LdaModel
from gensim.corpora import Dictionary
from gensim import corpora
import pandas as pd
import numpy as np
import pyLDAvis.gensim
from nltk.tokenize import TweetTokenizer
from nltk.corpus import stopwords
import string

# %%
#importamos los datos desde un csv
df_tweet = pd.read_csv("data/Salvemos las dos vidas.csv", sep = "+")

# %%
palabrasqueno = ['aborto','https', '#salvemoslas2vidas','#noalabortoenargentina','…', '¿', '•', '#rusia2018', '#copa2018', '#todavidavale', '#argentinaesprovida', '#salvemoslasdosvidas', '#sialavida', '#abortosesionhistorica', 'rt']
stopwords = stopwords.words('spanish')+list(string.punctuation)+ palabrasqueno

# %%
# procesar tweet
def procesar_tweet(text, tokenizer=TweetTokenizer(), stopwords=[]):
    
    '''Funcion para procesar Tweets que recibe un tweets, un objeto
    que servirá para tokenizar los tweet y una lista de stopwords'''
    text = text.lower()
    tokens = tokenizer.tokenize(text)
    return [tok for tok in tokens if tok not in stopwords]

# %%
tknzr = TweetTokenizer()
topicos = dict()
i = 0
for tweet in df_tweet.Text:
    topicos[i] = procesar_tweet(tweet, tknzr, stopwords)
    i+=1

# %%
lista = [x for x in topicos.values()]
dictionary = corpora.Dictionary(lista)
print (len(dictionary))
# Out:
# 6162

# %%
corpus = [dictionary.doc2bow(text) for text in lista]
ldamodel = LdaModel(corpus = corpus, num_topics = 5, id2word = dictionary, iterations = 2000, passes = 10)
ldamodel.print_topics (5, 10)
# Out:
# [(0,
#   '0.029*"vidas" + 0.024*"salvar" + 0.018*"si" + 0.017*"médicos" + 0.014*"claro" + 0.014*":/" + 0.014*"felicito" + 0.013*"grande" + 0.013*"@elcoya1977" + 0.013*"vocación"'),
#  (1,
#   '0.022*"hoy" + 0.018*"llegamos" + 0.014*"argentina" + 0.011*"concentración" + 0.011*"campos" + 0.011*"esperanza" + 0.011*"gracias" + 0.011*"@unidadprovida" + 0.011*"siempre" + 0.011*"clínicas"'),
#  (2,
#   '0.016*"algún" + 0.015*"vida" + 0.014*"dicen" + 0.012*"cuenten" + 0.011*"médicos" + 0.011*"conmigo" + 0.011*"@altamirano_maxi" + 0.010*"@majuliavega" + 0.010*"#siala" + 0.010*"#yonovotopoliticosabortistas"'),
#  (3,
#   '0.024*"si" + 0.020*"nacer" + 0.019*"mundo" + 0.017*"hoy" + 0.016*"@pabmartinez" + 0.015*"permitió" + 0.015*"admira" + 0.015*"https://t.co/resrr7l…" + 0.014*"vida" + 0.012*"muerte"'),
#  (4,
#   '0.030*"derecho" + 0.026*"“" + 0.023*"vida" + 0.019*"”" + 0.016*"vamos" + 0.014*"mujeres" + 0.013*"humano" + 0.011*"ser" + 0.011*"@dipnataliavilla" + 0.010*"eliminarla"')]

# %%
pyLDAvis.enable_notebook()
pyLDAvis.gensim.prepare(ldamodel, corpus, dictionary, mds="tsne")
# Out:
# WARNING:root:sklearn not present, switch to PCoA
# PreparedData(topic_coordinates=            Freq  cluster  topics         x         y
# topic
# 1      22.768536        1       1 -0.196792 -0.049298
# 3      20.746317        1       2 -0.124578 -0.162343
# 4      20.039064        1       3  0.232747 -0.122176
# 0      18.561144        1       4 -0.032351  0.273097
# 2      17.884943        1       5  0.120974  0.060720, topic_info=     Category        Freq                   Term       Total  loglift  logprob
# term
# 4093  Default  287.000000                derecho  287.000000  30.0000  30.0000
# 1461  Default  340.000000                  vidas  340.000000  29.0000  29.0000
# 1542  Default  312.000000                      “  312.000000  28.0000  28.0000
# 5565  Default  224.000000                 salvar  224.000000  27.0000  27.0000
# 6015  Default  188.000000                  mundo  188.000000  26.0000  26.0000
# 969   Default  197.000000               llegamos  197.000000  25.0000  25.0000
# 3501  Default  439.000000                    hoy  439.000000  24.0000  24.0000
# 5507  Default  227.000000                  nacer  227.000000  23.0000  23.0000
# 4881  Default  207.000000                      ”  207.000000  22.0000  22.0000
# 4634  Default  245.000000                médicos  245.000000  21.0000  21.0000
# 4017  Default  155.000000                  vamos  155.000000  20.0000  20.0000
# 234   Default  153.000000           @pabmartinez  153.000000  19.0000  19.0000
# 5394  Default  137.000000                  algún  137.000000  18.0000  18.0000
# 5765  Default  147.000000               permitió  147.000000  17.0000  17.0000
# 2547  Default  462.000000                     si  462.000000  16.0000  16.0000
# 4381  Default  145.000000                 admira  145.000000  15.0000  15.0000
# 4192  Default  145.000000  https://t.co/resrr7l…  145.000000  14.0000  14.0000
# 682   Default  123.000000                  claro  123.000000  13.0000  13.0000
# 4783  Default  122.000000                     :/  122.000000  12.0000  12.0000
# 1432  Default  119.000000                  dicen  119.000000  11.0000  11.0000
# 5835  Default  121.000000               felicito  121.000000  10.0000  10.0000
# 6121  Default  213.000000                mujeres  213.000000   9.0000   9.0000
# 4073  Default  119.000000                 grande  119.000000   8.0000   8.0000
# 3997  Default  119.000000            @elcoya1977  119.000000   7.0000   7.0000
# 2431  Default  116.000000         interrumpirlas  116.000000   6.0000   6.0000
# 5861  Default  116.000000              eligieron  116.000000   5.0000   5.0000
# 2447  Default  116.000000               vocación  116.000000   4.0000   4.0000
# 3670  Default  108.000000               juventud  108.000000   3.0000   3.0000
# 6131  Default  123.000000                 campos  123.000000   2.0000   2.0000
# 5910  Default  123.000000          concentración  123.000000   1.0000   1.0000
# ...       ...         ...                    ...         ...      ...      ...
# 5576   Topic5   41.714622               seguimos   42.429291   1.7042  -5.3151
# 1918   Topic5   41.386627                 chicas   42.098000   1.7042  -5.3230
# 630    Topic5   40.108402               votación   40.822353   1.7036  -5.3544
# 5654   Topic5   39.908897                   zona   40.620289   1.7035  -5.3594
# 4364   Topic5   39.695099                  amigo   40.406742   1.7034  -5.3647
# 5658   Topic5   39.170063               atrapado   39.881435   1.7032  -5.3781
# 1741   Topic5   39.170063                 charly   39.881435   1.7032  -5.3781
# 1113   Topic5   39.170063                 tomado   39.881435   1.7032  -5.3781
# 504    Topic5   39.170063                  quedó   39.881435   1.7032  -5.3781
# 3475   Topic5   35.169971                    hac   35.881340   1.7012  -5.4858
# 6134   Topic5   34.925415               valentía   35.642208   1.7009  -5.4928
# 5056   Topic5   33.921211                 libera   34.632618   1.7005  -5.5219
# 987    Topic5   33.395954                   crea   34.107323   1.7001  -5.5375
# 2172   Topic5   33.395954             mujer.sino   34.107323   1.7001  -5.5375
# 910    Topic5   33.395954               pasiones   34.107323   1.7001  -5.5375
# 2461   Topic5   33.395954             vengativas   34.107323   1.7001  -5.5375
# 4064   Topic5   33.395954                  chica   34.107323   1.7001  -5.5375
# 5337   Topic5   33.395954                  presa   34.107323   1.7001  -5.5375
# 4745   Topic5   31.079369           #leydeaborto   31.790785   1.6986  -5.6094
# 741    Topic5   71.408592                pañuelo   97.498131   1.4098  -4.7775
# 3005   Topic5   52.844753                   niño   67.691414   1.4736  -5.0786
# 5555   Topic5   75.802841                      ¡  138.145050   1.1210  -4.7178
# 4634   Topic5   95.224701                médicos  245.829453   0.7728  -4.4897
# 1443   Topic5   71.498070                    día  167.530670   0.8697  -4.7763
# 4749   Topic5  129.376404                   vida  594.332581   0.1965  -4.1832
# 6121   Topic5   76.470528                mujeres  213.834717   0.6929  -4.7091
# 2025   Topic5   40.054161              violencia   54.691807   1.4097  -5.3557
# 51     Topic5   55.471973                    ...  170.497787   0.5984  -5.0301
# 3831   Topic5   46.928009                    ver  101.764709   0.9472  -5.1974
# 2241   Topic5   47.754459                gracias  263.664093   0.0126  -5.1799
#
# [245 rows x 6 columns], token_table=      Topic      Freq                          Term
# term
# 3510      1  0.158952                       #aborto
# 3510      3  0.628585                       #aborto
# 3510      5  0.209528                       #aborto
# 57        3  0.972623                  #abortolegal
# 530       1  0.966145                  #bahiablanca
# 4745      5  0.975125                  #leydeaborto
# 4439      4  0.986315              #salvemoslas2vid
# 332       5  0.993961                        #siala
# 714       5  0.993111  #yonovotopoliticosabortistas
# 51        1  0.258068                           ...
# 51        2  0.152495                           ...
# 51        3  0.117304                           ...
# 51        4  0.146629                           ...
# 51        5  0.322585                           ...
# 435       4  0.992742                             2
# 4551      2  0.987441                           500
# 5884      2  0.990067                            60
# 4783      4  0.996312                            :/
# 3085      2  0.991937                @_nicocorbalan
# 4232      5  0.993298              @altamirano_maxi
# 2879      1  0.325727              @anabelenmarmora
# 2879      3  0.670615              @anabelenmarmora
# 2806      3  0.975077                          @c5n
# 1788      3  0.985671                    @cristiano
# 2631      3  0.996053              @dipnataliavilla
# 3997      4  0.990765                   @elcoya1977
# 6043      2  0.990331                 @estebanschab
# 1885      1  0.985416                  @fcosampieri
# 2142      1  0.984694               @florantonuccih
# 3225      1  0.451004                @frentejovenar
# ...     ...       ...                           ...
# 3831      4  0.039306                           ver
# 3831      5  0.461850                           ver
# 2992      1  0.050245                           vez
# 2992      2  0.653187                           vez
# 2992      4  0.288910                           vez
# 4749      1  0.159843                          vida
# 4749      2  0.232193                          vida
# 4749      3  0.368481                          vida
# 4749      4  0.021873                          vida
# 4749      5  0.217050                          vida
# 1461      1  0.258811                         vidas
# 1461      4  0.741141                         vidas
# 3126      2  0.987441                          viky
# 656       4  0.990473                           vio
# 3502      1  0.974620                    violadores
# 2025      1  0.255980                     violencia
# 2025      5  0.731371                     violencia
# 1269      1  0.994963                        vistas
# 2447      4  0.997330                      vocación
# 630       5  0.979855                      votación
# 3684      3  0.992758                       víctima
# 5654      5  0.984730                          zona
# 5555      4  0.448804                             ¡
# 5555      5  0.550146                             ¡
# 141       4  0.986562                         ángel
# 1542      2  0.214293                             “
# 1542      3  0.783608                             “
# 4881      2  0.129858                             ”
# 4881      3  0.865721                             ”
# 2577      2  0.984873                             ✔
#
# [289 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[2, 4, 5, 1, 3])
